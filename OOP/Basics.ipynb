# %%
class myClass:
    x = 5
    
p1 = myClass()
print(p1.x)

del p1
p1 = myClass()
print(p1.x)

p2 = myClass()
p3 = myClass()

print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5
# 5

# %%
class Person:
    def __init__(self, name, age = 18):
        self.name = name
        self.age = age
        
p1 = Person("Emon Rahman", 23)

print(p1.name, p1.age)

# default value init
p2 = Person("Mohammad")
print(p2.name, p2.age)
# Out:
# Emon Rahman 23
# Mohammad 18

# %%
class details:
    def __init__(self, name, city, country):
        self.name = name
        self.city = city 
        self.country = country
        
p5 = details("Emon", "Dhaka", "BD")
print(p5.name, p5.city, p5.country)
# Out:
# Emon Dhaka BD

# %% [markdown]
# # USE SELF TO ACCESS CLASS PROPERTIES

# %%
class Person:
    species = "HUMAN"
    def __init__(self, name, age = 18):
        self.name = name
        self.age = age
        
    def greet(self):
        print("HELLO, MY NAME IS " + self.name)
        
    def welcome(self):
        message = self.greet()
        print(message , "! Welcome to VS code.")    
        
p7 = Person("EMON RAHMAN")

p7.greet()
p7.welcome()
print(p7.species)

Person.species = "Adult"
print(p7.species)
# Out:
# HELLO, MY NAME IS EMON RAHMAN
# HELLO, MY NAME IS EMON RAHMAN
# None ! Welcome to VS code.
# HUMAN
# Adult

# %%
class Car:
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year
        
    def display_info(self):
        print(f"{self.year} {self.brand} {self.model}")
        
car1 = Car("Toyota", "Corolla", "2020")
car1.display_info()

car1.city = "Japan"
car1.display_info()
print(car1.city)
# Out:
# 2020 Toyota Corolla
# 2020 Toyota Corolla
# Japan

# %%
class Calculator:
    def __init__(self, a, b):
        self.a = a
        self.b = b
    def add(self):
        return self.a + self.b
    def multiply(self):
        return self.a * self.b
    def increement(self):
        self.a += 1
        self.b += 1
        print(f"Increemntal number is: {self.a, self.b}")
    
calc = Calculator(5, 2)
print(calc.add())
print(calc.multiply())

calc.increement()

del Calculator.increement
# Out:
# 7
# 10
# Increemntal number is: (6, 3)

# %%
class Person:
    species = "HUMAN"
    def __init__(self, name, age = 18):
        self.name = name
        self.age = age
        
    # STRING METHOD
    def __str__(self):
        return f"{self.name} {self.age}"      
        
p7 = Person("EMON RAHMAN")
print(p7)
# Out:
# EMON RAHMAN 18

# %%
class Playlist:
    def __init__(self, name):
        self.name = name 
        self.songs = []
        
    def add_songs(self, song):
        self.songs.append(song)
        print(f"Added: {song}")
        
    def remove_songs(self,song):
        if song in self.songs:
            self.songs.remove(song)
            print(f"Removed: {song}")
    
    def show_songs(self):
        print(f"Playlist '{self.name}': ")
        for song in self.songs:
            print(f"- {song}")
            
my_playlist = Playlist("Favourites")
my_playlist.add_songs("LET ME DOWN SLOWLY...")
my_playlist.add_songs("STAIRWAYS TO HEAVEN...")

my_playlist.show_songs()
# Out:
# Added: LET ME DOWN SLOWLY...
# Added: STAIRWAYS TO HEAVEN...
# Playlist 'Favourites':
# - LET ME DOWN SLOWLY...
# - STAIRWAYS TO HEAVEN...
